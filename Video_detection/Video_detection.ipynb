# %%
import numpy as np
import cv2
import time

# %% [markdown]
# <h3> Algorithm:
#
#
#  Reading input video --> Loading YOLO v3 Network -->
#
#  --> Reading frames in the loop --> Getting blob from the frame -->
#
#  --> Implementing Forward Pass --> Getting Bounding Boxes -->
#
#  --> Non-maximum Suppression --> Drawing Bounding Boxes with Labels -->
#
#  --> Writing processed frames
#
#  Result:
#  New video file with Detected Objects, Bounding Boxes and Labels

# %%
##############################################
######   Reading input video    #############
############################################

video = cv2.VideoCapture('vid.mp4')

# Preparing variable for writer
# that we will use to write processed frames
writer = None

# Preparing variables for spatial dimensions of the frames
h, w = None, None


##############################################
#####    Loading YOLO v3 Network    #########
############################################

with open('yolo-coco-data/coco.names') as f:
    # Getting labels reading every line
    # and putting them into the list
    labels = [line.strip() for line in f]
    
network = cv2.dnn.readNetFromDarknet('yolo-coco-data/yolov3.cfg',
                                     'yolo-coco-data/yolov3.weights')

# Getting list with names of all layers from YOLO v3 network
layers_names_all = network.getLayerNames()
layers_names_output = \
    [layers_names_all[i[0] - 1] for i in network.getUnconnectedOutLayers()]
# Setting minimum probability to eliminate weak predictions
probability_minimum = 0.5

# Setting threshold for filtering weak bounding boxes
# with non-maximum suppression
threshold = 0.3

# Generating colours for representing every detected object
# with function randint(low, high=None, size=None, dtype='l')
colours = np.random.randint(0, 255, size=(len(labels), 3), dtype='uint8')


###############################################
#######     Reading frames in the loop   #####
#############################################

# Defining variable for counting frames
# At the end we will show total amount of processed frames
f = 0

# Defining variable for counting total time
# At the end we will show time spent for processing all frames
t = 0

# Defining loop for catching frames
while True:
    # Capturing frame-by-frame
    ret, frame = video.read()
    
    # If the frame was not retrieved
    # e.g.: at the end of the video,
    # then we break the loop
    if not ret:
        break

    # Getting spatial dimensions of the frame
    # we do it only once from the very beginning
    # all other frames have the same dimension
    if w is None or h is None:
        # Slicing from tuple only first two elements
        h, w = frame.shape[:2]
        
###############################################
######     Getting blob from the frame   #####
#############################################        

    # cv2.dnn.blobFromImag() : facilitate image preprocessing for deep learning classification:
    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0,(416, 416), swapRB=True, crop=False)
    
    
##############################################
#######    Implementing Forward Pass  #######
############################################

    # Implementing forward pass with our blob and only through output layers
    # Calculating at the same time, needed time for forward pass
    network.setInput(blob)  # setting blob as input to the network
    start = time.time()
    output_from_network = network.forward(layers_names_output)
    end = time.time()

    # Increasing counters for frames and total time
    f += 1
    t += end - start

    # Showing spent time for single current frame
    print('Frame number {0} took {1:.5f} seconds'.format(f, end - start))
    
    
#####################################################
######      Getting Bounding Boxes    ##############
####################################################
    
    bounding_boxes = []
    confidences = []
    class_numbers = []

    # Going through all output layers after feed forward pass
    for result in output_from_network:
        # Going through all detections from current output layer
        for detected_objects in result:
            # Getting 80 classes' probabilities for current detected object
            scores = detected_objects[5:]
            # Getting index of the class with the maximum value of probability
            class_current = np.argmax(scores)
            # Getting value of probability for defined class
            confidence_current = scores[class_current]
            
            
            if confidence_current > probability_minimum:
                # Scaling bounding box coordinates to the initial frame size
                # YOLO data format keeps coordinates for center of bounding box
                # and its current width and height
                # That is why we can just multiply them elementwise
                # to the width and height
                # of the original frame and in this way get coordinates for center
                # of bounding box, its width and height for original frame
                box_current = detected_objects[0:4] * np.array([w, h, w, h])

                # Now, from YOLO data format, we can get top left corner coordinates
                # that are x_min and y_min
                x_center, y_center, box_width, box_height = box_current
                x_min = int(x_center - (box_width / 2))
                y_min = int(y_center - (box_height / 2))

                # Adding results into prepared lists
                bounding_boxes.append([x_min, y_min,
                                       int(box_width), int(box_height)])
                confidences.append(float(confidence_current))
                class_numbers.append(class_current)
                
                
##########################################################
########    Non-maximum suppression  ###################
######################################################


    # Implementing non-maximum suppression of given bounding boxes
    # With this technique we exclude some of bounding boxes if their
    # corresponding confidences are low or there is another
    # bounding box for this region with higher confidence
    
    results = cv2.dnn.NMSBoxes(bounding_boxes, confidences,
                               probability_minimum, threshold)
    
    
######################################################
########    Drawing bounding boxes and labels  #####
######################################################
    
    if len(results) > 0:
        # Going through indexes of results
        for i in results.flatten():
            # Getting current bounding box coordinates,
            # its width and height
            x_min, y_min = bounding_boxes[i][0], bounding_boxes[i][1]
            box_width, box_height = bounding_boxes[i][2], bounding_boxes[i][3]

            # Preparing colour for current bounding box
            # and converting from numpy array to list
            colour_box_current = colours[class_numbers[i]].tolist()

            # # # Check point
            # print(type(colour_box_current))  # <class 'list'>
            # print(colour_box_current)  # [172 , 10, 127]

            # Drawing bounding box on the original current frame
            cv2.rectangle(frame, (x_min, y_min),
                          (x_min + box_width, y_min + box_height),
                          colour_box_current, 2)

            # Preparing text with label and confidence for current bounding box
            text_box_current = '{}: {:.4f}'.format(labels[int(class_numbers[i])],
                                                   confidences[i])

            # Putting text with label and confidence on the original image
            cv2.putText(frame, text_box_current, (x_min, y_min - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, colour_box_current, 2)
            
            
####################################################################
##############       Writing processed frame into the file   ######
###################################################################

    # Initializing writer
    # we do it only once from the very beginning
    # when we get spatial dimensions of the frames
    if writer is None:
        # Constructing code of the codec
        # to be used in the function VideoWriter
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')

        # Writing current processed frame into the video file
        # Pay attention! If you're using Windows, yours path might looks like:
        # r'videos\result-traffic-cars.mp4'
        # or:
        # 'videos\\result-traffic-cars.mp4'
        writer = cv2.VideoWriter('result-vid.mp4', fourcc, 30,
                                 (frame.shape[1], frame.shape[0]), True)

    # Write processed current frame to the file
    writer.write(frame)
    
    
#######################################################
#########   Reading frames in the loop  ###############
######################################################

print()
print('Total number of frames', f)
print('Total amount of time {:.5f} seconds'.format(t))
print('FPS:', round((f / t), 1))


# Releasing video reader and writer
video.release()
writer.release()
# Out:
# Frame number 1 took 1.04158 seconds
# Frame number 2 took 0.55053 seconds
# Frame number 3 took 0.55348 seconds
# Frame number 4 took 0.54455 seconds
# Frame number 5 took 0.54554 seconds
# Frame number 6 took 0.58045 seconds
# Frame number 7 took 0.53656 seconds
# Frame number 8 took 0.61835 seconds
# Frame number 9 took 0.61735 seconds
# Frame number 10 took 0.62333 seconds
# Frame number 11 took 0.56746 seconds
# Frame number 12 took 0.56748 seconds
# Frame number 13 took 0.58643 seconds
# Frame number 14 took 0.59241 seconds
# Frame number 15 took 0.60540 seconds
# Frame number 16 took 0.60938 seconds
# Frame number 17 took 0.59740 seconds
# Frame number 18 took 0.55452 seconds
# Frame number 19 took 0.57544 seconds
# Frame number 20 took 0.53158 seconds
# Frame number 21 took 0.54953 seconds
# Frame number 22 took 0.54454 seconds
# Frame number 23 took 0.57746 seconds
# Frame number 24 took 0.55847 seconds
# Frame number 25 took 0.54754 seconds
# Frame number 26 took 0.63131 seconds
# Frame number 27 took 0.59142 seconds
# Frame number 28 took 0.58743 seconds
# Frame number 29 took 0.68915 seconds
# Frame number 30 took 0.53756 seconds
# Frame number 31 took 0.48171 seconds
# Frame number 32 took 0.53157 seconds
# Frame number 33 took 0.53158 seconds
# Frame number 34 took 0.54754 seconds
# Frame number 35 took 0.48371 seconds
# Frame number 36 took 0.48071 seconds
# Frame number 37 took 0.48371 seconds
# Frame number 38 took 0.47972 seconds
# Frame number 39 took 0.48168 seconds
# Frame number 40 took 0.48969 seconds
# Frame number 41 took 0.51861 seconds
# Frame number 42 took 0.51163 seconds
# Frame number 43 took 0.49170 seconds
# Frame number 44 took 0.48371 seconds
# Frame number 45 took 0.50066 seconds
# Frame number 46 took 0.52360 seconds
# Frame number 47 took 0.47972 seconds
# Frame number 48 took 0.48767 seconds
# Frame number 49 took 0.48469 seconds
# Frame number 50 took 0.47573 seconds
# Frame number 51 took 0.49867 seconds
# Frame number 52 took 0.48171 seconds
# Frame number 53 took 0.48570 seconds
# Frame number 54 took 0.49567 seconds
# Frame number 55 took 0.46873 seconds
# Frame number 56 took 0.46675 seconds
# Frame number 57 took 0.48768 seconds
# Frame number 58 took 0.48171 seconds
# Frame number 59 took 0.48869 seconds
# Frame number 60 took 0.48467 seconds
# Frame number 61 took 0.48171 seconds
# Frame number 62 took 0.49368 seconds
# Frame number 63 took 0.53753 seconds
# Frame number 64 took 0.47672 seconds
# Frame number 65 took 0.51464 seconds
# Frame number 66 took 0.51558 seconds
# Frame number 67 took 0.47972 seconds
# Frame number 68 took 0.49069 seconds
# Frame number 69 took 0.48869 seconds
# Frame number 70 took 0.48371 seconds
# Frame number 71 took 0.50665 seconds
# Frame number 72 took 0.48570 seconds
# Frame number 73 took 0.48669 seconds
# Frame number 74 took 0.48171 seconds
# Frame number 75 took 0.48670 seconds
# Frame number 76 took 0.48770 seconds
# Frame number 77 took 0.48668 seconds
# Frame number 78 took 0.48667 seconds
# Frame number 79 took 0.48567 seconds
# Frame number 80 took 0.49963 seconds
# Frame number 81 took 0.48371 seconds
# Frame number 82 took 0.49465 seconds
# Frame number 83 took 0.47074 seconds
# Frame number 84 took 0.47972 seconds
# Frame number 85 took 0.51060 seconds
# Frame number 86 took 0.47672 seconds
# Frame number 87 took 0.48470 seconds
# Frame number 88 took 0.49666 seconds
# Frame number 89 took 0.48171 seconds
# Frame number 90 took 0.48268 seconds
# Frame number 91 took 0.48670 seconds
# Frame number 92 took 0.53158 seconds
# Frame number 93 took 0.52260 seconds
# Frame number 94 took 0.50066 seconds
# Frame number 95 took 0.50461 seconds
# Frame number 96 took 0.48764 seconds
# Frame number 97 took 0.47970 seconds
# Frame number 98 took 0.49068 seconds
# Frame number 99 took 0.49767 seconds
# Frame number 100 took 0.46276 seconds
# Frame number 101 took 0.47872 seconds
# Frame number 102 took 0.48470 seconds
# Frame number 103 took 0.49867 seconds
# Frame number 104 took 0.48368 seconds
# Frame number 105 took 0.47570 seconds
# Frame number 106 took 0.47972 seconds
# Frame number 107 took 0.48271 seconds
# Frame number 108 took 0.48470 seconds
# Frame number 109 took 0.47772 seconds
# Frame number 110 took 0.47074 seconds
# Frame number 111 took 0.47872 seconds
# Frame number 112 took 0.46971 seconds
# Frame number 113 took 0.48371 seconds
# Frame number 114 took 0.50764 seconds
# Frame number 115 took 0.47569 seconds
# Frame number 116 took 0.48770 seconds
# Frame number 117 took 0.48470 seconds
# Frame number 118 took 0.47473 seconds
# Frame number 119 took 0.47373 seconds
# Frame number 120 took 0.48371 seconds
# Frame number 121 took 0.49169 seconds
# Frame number 122 took 0.53357 seconds
# Frame number 123 took 0.50066 seconds
# Frame number 124 took 0.52259 seconds
# Frame number 125 took 0.47472 seconds
# Frame number 126 took 0.48869 seconds
# Frame number 127 took 0.49268 seconds
# Frame number 128 took 0.46875 seconds
# Frame number 129 took 0.48168 seconds
# Frame number 130 took 0.49268 seconds
# Frame number 131 took 0.47574 seconds
# Frame number 132 took 0.48969 seconds
# Frame number 133 took 0.48371 seconds
# Frame number 134 took 0.48670 seconds
# Frame number 135 took 0.49966 seconds
# Frame number 136 took 0.48271 seconds
# Frame number 137 took 0.48570 seconds
# Frame number 138 took 0.49069 seconds
# Frame number 139 took 0.47773 seconds
# Frame number 140 took 0.49169 seconds
# Frame number 141 took 0.48370 seconds
# Frame number 142 took 0.49367 seconds
# Frame number 143 took 0.48969 seconds
# Frame number 144 took 0.48868 seconds
# Frame number 145 took 0.48171 seconds
# Frame number 146 took 0.49667 seconds
# Frame number 147 took 0.47972 seconds
# Frame number 148 took 0.47372 seconds
# Frame number 149 took 0.49168 seconds
# Frame number 150 took 0.48670 seconds
# Frame number 151 took 0.52859 seconds
# Frame number 152 took 0.52161 seconds
# Frame number 153 took 0.48769 seconds
# Frame number 154 took 0.50063 seconds
# Frame number 155 took 0.47871 seconds
# Frame number 156 took 0.48869 seconds
# Frame number 157 took 0.48071 seconds
# Frame number 158 took 0.47969 seconds
# Frame number 159 took 0.48367 seconds
# Frame number 160 took 0.47873 seconds
# Frame number 161 took 0.47972 seconds
# Frame number 162 took 0.49368 seconds
# Frame number 163 took 0.47872 seconds
# Frame number 164 took 0.47972 seconds
# Frame number 165 took 0.48271 seconds
# Frame number 166 took 0.48670 seconds
# Frame number 167 took 0.48969 seconds
# Frame number 168 took 0.47872 seconds
# Frame number 169 took 0.49169 seconds
# Frame number 170 took 0.48171 seconds
# Frame number 171 took 0.48467 seconds
# Frame number 172 took 0.48171 seconds
# Frame number 173 took 0.51062 seconds
# Frame number 174 took 0.48969 seconds
# Frame number 175 took 0.48271 seconds
# Frame number 176 took 0.48969 seconds
# Frame number 177 took 0.47672 seconds
# Frame number 178 took 0.47273 seconds
# Frame number 179 took 0.48371 seconds
# Frame number 180 took 0.48168 seconds
# Frame number 181 took 0.52759 seconds
# Frame number 182 took 0.52759 seconds
# Frame number 183 took 0.50864 seconds
# Frame number 184 took 0.49268 seconds
# Frame number 185 took 0.48769 seconds
# Frame number 186 took 0.47074 seconds
# Frame number 187 took 0.48371 seconds
# Frame number 188 took 0.49369 seconds
# Frame number 189 took 0.48470 seconds
# Frame number 190 took 0.48969 seconds
# Frame number 191 took 0.49168 seconds
# Frame number 192 took 0.48470 seconds
# Frame number 193 took 0.46974 seconds
# Frame number 194 took 0.48370 seconds
# Frame number 195 took 0.47573 seconds
# Frame number 196 took 0.49269 seconds
# Frame number 197 took 0.49069 seconds
# Frame number 198 took 0.48271 seconds
# Frame number 199 took 0.48470 seconds
# Frame number 200 took 0.48969 seconds
# Frame number 201 took 0.48769 seconds
# Frame number 202 took 0.48371 seconds
# Frame number 203 took 0.48969 seconds
# Frame number 204 took 0.48371 seconds
# Frame number 205 took 0.48371 seconds
# Frame number 206 took 0.49069 seconds
# Frame number 207 took 0.50163 seconds
# Frame number 208 took 0.48869 seconds
# Frame number 209 took 0.47470 seconds
# Frame number 210 took 0.50266 seconds
# Frame number 211 took 0.54352 seconds
# Frame number 212 took 0.49066 seconds
# Frame number 213 took 0.53856 seconds
# Frame number 214 took 0.49168 seconds
# Frame number 215 took 0.47973 seconds
# Frame number 216 took 0.48072 seconds
# Frame number 217 took 0.47670 seconds
# Frame number 218 took 0.49265 seconds
# Frame number 219 took 0.47373 seconds
# Frame number 220 took 0.48569 seconds
# Frame number 221 took 0.48571 seconds
# Frame number 222 took 0.48969 seconds
# Frame number 223 took 0.47772 seconds
# Frame number 224 took 0.48271 seconds
# Frame number 225 took 0.49169 seconds
# Frame number 226 took 0.49066 seconds
# Frame number 227 took 0.48570 seconds
# Frame number 228 took 0.48371 seconds
# Frame number 229 took 0.48072 seconds
# Frame number 230 took 0.48668 seconds
# Frame number 231 took 0.48371 seconds
# Frame number 232 took 0.48570 seconds
# Frame number 233 took 0.50263 seconds
# Frame number 234 took 0.48071 seconds
# Frame number 235 took 0.47972 seconds
# Frame number 236 took 0.49168 seconds
# Frame number 237 took 0.47574 seconds
# Frame number 238 took 0.48071 seconds
# Frame number 239 took 0.48570 seconds
# Frame number 240 took 0.53557 seconds
# Frame number 241 took 0.51961 seconds
#
# Total number of frames 241
# Total amount of time 121.15616 seconds
# FPS: 2.0
